# %% [markdown]
# <a href="https://colab.research.google.com/github/theaok/gisPy/blob/main/examples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### https://www.reddit.com/r/MapPorn

# %% [markdown]
# Percentage of people trust climate scientists

# %% [markdown]
# ![bqaeqht0829a1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Nordic Ancestry in USA

# %% [markdown]
# ![Screenshot_2023-10-17 r MapPorn - Nordic Ancestry in USA.png](data:image/png;base64,...)

# %% [markdown]
# Mass suicide attempts in India

# %% [markdown]
# ![Screenshot_2023-10-17 i0gdqb1cbbrb1 jpg (JPEG Image, 3000 × 3000 pixels).png](data:image/png;base64,...)

# %% [markdown]
# ### https://www.visualcapitalist.com/

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
